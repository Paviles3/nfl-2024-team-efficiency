# %% [markdown]
# # 🏈 NFL 2024 Team Efficiency Analysis
#
# This notebook explores relationships between key team metrics and wins for the 2024 NFL season.

# %% [markdown]
# ## 1) Setup & Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("NFL_2024_Stats.csv")

# Show the first few rows
df.head()
# Out:
#                    Team  Games Played  Wins  Losses  Points Scored  \
# 0         Buffalo Bills            17    13       4            525
# 1        Miami Dolphins            17     8       9            345
# 2         New York Jets            17     5      12            338
# 3  New England Patriots            17     4      13            289
# 4      Baltimore Ravens            17    12       5            518
#
#    Points Allowed  Total Yards  Passing Yards  Rushing Yards  Turnovers  \
# 0             368         6105           3875           2230          8
# 1             364         5532           3737           1795         21
# 2             404         5275           3714           1561         19
# 3             417         4964           2995           1969         23
# 4             361         7224           4035           3189         11
#
#    Third Down %  Red Zone TD %
# 0          44.1           71.6
# 1          36.3           56.6
# 2          39.5           54.5
# ...

# %% [markdown]
# ## 2) Quick Data Check

# %%
# Check for nulls or weird values
print(df.info())

# Get summary statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Team            32 non-null     object
#  1   Games Played    32 non-null     int64
#  2   Wins            32 non-null     int64
#  3   Losses          32 non-null     int64
#  4   Points Scored   32 non-null     int64
#  5   Points Allowed  32 non-null     int64
#  6   Total Yards     32 non-null     int64
#  7   Passing Yards   32 non-null     int64
#  8   Rushing Yards   32 non-null     int64
#  9   Turnovers       32 non-null     int64
#  10  Third Down %    32 non-null     float64
#  11  Red Zone TD %   32 non-null     float64
# dtypes: float64(2), int64(9), object(1)
# memory usage: 3.1+ KB
# None
#        Games Played       Wins     Losses  Points Scored  Points Allowed  \
# count          32.0  32.000000  32.000000       32.00000       32.000000
# ...

# %% [markdown]
# ## 3) Visuals
#
# ### A) Top/Bottom 10 Teams by Points Scored

# %%
# Top 10 Teams by Points Scored

top_10_pts_scored = df.sort_values("Points Scored", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10_pts_scored["Team"], top_10_pts_scored["Points Scored"], color="forestgreen")
plt.title("Top 10 Teams by Points Scored (2024)")
plt.xlabel("Team")
plt.ylabel("Points Scored")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bottom 10 Teams by Points Scored

bottom_10_pts_scored = df.sort_values("Points Scored").head(10)

plt.figure(figsize=(12, 6))
plt.bar(bottom_10_pts_scored["Team"], bottom_10_pts_scored["Points Scored"], color="crimson")
plt.title("Bottom 10 Teams by Points Scored (2024)")
plt.xlabel("Team")
plt.ylabel("Points Scored")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### B) Top/Bottom 10 Teams by Points Allowed

# %%
# Top 10 Teams by Points Allowed (Teams that allowed the most points)

top_10_pts_allowed = df.sort_values("Points Allowed", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10_pts_allowed["Team"], top_10_pts_allowed["Points Allowed"], color="crimson")
plt.title("Top 10 Teams by Points Allowed (2024)")
plt.xlabel("Team")
plt.ylabel("Points Allowed")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bottom 10 Teams by Points Allowed (Teams that allowed the fewest points)

bottom_10_pts_allowed = df.sort_values("Points Allowed").head(10)

plt.figure(figsize=(12, 6))
plt.bar(bottom_10_pts_allowed["Team"], bottom_10_pts_allowed["Points Allowed"], color="forestgreen")
plt.title("Bottom 10 Teams by Points Allowed (2024)")
plt.xlabel("Team")
plt.ylabel("Points Allowed")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### C) Top/Bottom 10 Teams by Total Yards

# %%
# Top 10 Teams by Total Yards (Teams with most yards)

top_10_tot_yds = df.sort_values("Total Yards", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10_tot_yds["Team"], top_10_tot_yds["Total Yards"], color="forestgreen")
plt.title("Top 10 Teams by Total Yards (2024)")
plt.xlabel("Team")
plt.ylabel("Total Yards")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bottom 10 Teams by Total Yards (Teams with fewest yards)

bottom_10_tot_yds = df.sort_values("Total Yards").head(10)

plt.figure(figsize=(12, 6))
plt.bar(bottom_10_tot_yds["Team"], bottom_10_tot_yds["Total Yards"], color="crimson")
plt.title("Bottom 10 Teams by Total Yards (2024)")
plt.xlabel("Team")
plt.ylabel("Total Yards")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### D) Top/Bottom 10 Teams by Passing Yards

# %%
# Top 10 Teams by Passing Yards (Teams with most passing yards)

top_10_pass_yds = df.sort_values("Passing Yards", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10_pass_yds["Team"], top_10_pass_yds["Passing Yards"], color="forestgreen")
plt.title("Top 10 Teams by Passing Yards (2024)")
plt.xlabel("Team")
plt.ylabel("Passing Yards")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bottom 10 Teams by Passing Yards (Teams with fewest passing yards)

bottom_10_pass_yds = df.sort_values("Passing Yards").head(10)

plt.figure(figsize=(12, 6))
plt.bar(bottom_10_pass_yds["Team"], bottom_10_pass_yds["Passing Yards"], color="crimson")
plt.title("Bottom 10 Teams by Passing Yards (2024)")
plt.xlabel("Team")
plt.ylabel("Passing Yards")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### E) Top/Bottom 10 Teams by Rushing Yards

# %%
# Top 10 Teams by Rushing Yards (Teams with most rushing yards)

top_10_rush_yds = df.sort_values("Rushing Yards", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10_rush_yds["Team"], top_10_rush_yds["Rushing Yards"], color="forestgreen")
plt.title("Top 10 Teams by Rushing Yards (2024)")
plt.xlabel("Team")
plt.ylabel("Rushing Yards")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bottom 10 Teams by Rushing Yards (Teams with fewest rushing yards)

bottom_10_rush_yds = df.sort_values("Rushing Yards").head(10)

plt.figure(figsize=(12, 6))
plt.bar(bottom_10_rush_yds["Team"], bottom_10_rush_yds["Rushing Yards"], color="crimson")
plt.title("Bottom 10 Teams by Rushing Yards (2024)")
plt.xlabel("Team")
plt.ylabel("Rushing Yards")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### F) Top/Bottom 10 Teams with Turnovers

# %%
# Top 10 Teams with the Fewest Turnovers

fewest_turnovers = df.sort_values("Turnovers").head(10)

plt.figure(figsize=(12, 6))
plt.bar(fewest_turnovers["Team"], fewest_turnovers["Turnovers"], color="steelblue")
plt.title("Top 10 Teams with Fewest Turnovers (2024)")
plt.xlabel("Team")
plt.ylabel("Turnovers")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Top 10 Teams with the Most Turnovers (i.e., Worst in Ball Security)

most_turnovers = df.sort_values("Turnovers", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(most_turnovers["Team"], most_turnovers["Turnovers"], color="firebrick")
plt.title("Top 10 Teams with the Most Turnovers (2024)")
plt.xlabel("Team")
plt.ylabel("Turnovers")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### G) Top/Bottom 10 Teams by Third Down %

# %%
# Top 10 Teams by Third Down %

top_third_down = df.sort_values("Third Down %", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_third_down["Team"], top_third_down["Third Down %"], color="mediumseagreen")
plt.title("Top 10 Teams by Third Down % (2024)")
plt.xlabel("Team")
plt.ylabel("Third Down %")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bottom 10 Teams by Third Down %

bottom_third_down = df.sort_values("Third Down %").head(10)

plt.figure(figsize=(12, 6))
plt.bar(bottom_third_down["Team"], bottom_third_down["Third Down %"], color="tomato")
plt.title("Bottom 10 Teams by Third Down % (2024)")
plt.xlabel("Team")
plt.ylabel("Third Down %")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### H) Top/Bottom 10 Teams by Red Zone Touchdown %

# %%
# Top 10 Teams by Red Zone Touchdown %

top_redzone = df.sort_values("Red Zone TD %", ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_redzone["Team"], top_redzone["Red Zone TD %"], color="mediumseagreen")
plt.title("Top 10 Teams by Red Zone TD % (2024)")
plt.xlabel("Team")
plt.ylabel("Red Zone Touchdown %")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bottom 10 Teams by Red Zone Touchdown %

bottom_redzone = df.sort_values("Red Zone TD %").head(10)

plt.figure(figsize=(12, 6))
plt.bar(bottom_redzone["Team"], bottom_redzone["Red Zone TD %"], color="tomato")
plt.title("Bottom 10 Teams by Red Zone TD % (2024)")
plt.xlabel("Team")
plt.ylabel("Red Zone Touchdown %")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### I) Wins vs Total/Passing/Rushing Yards

# %%
# Scatter Plot: Wins vs Total Yards

plt.figure(figsize=(10, 6))
plt.scatter(df["Total Yards"], df["Wins"], color="purple")

plt.title("NFL 2024: Wins vs Total Yards")
plt.xlabel("Total Yards Gained")
plt.ylabel("Wins")

# Add team labels
for i in range(len(df)):
    plt.text(df["Total Yards"][i], df["Wins"][i], df["Team"][i], fontsize=8)

plt.grid(True)
plt.tight_layout()
plt.show()

# Wins vs Passing Yards

plt.figure(figsize=(10, 6))
plt.scatter(df["Passing Yards"], df["Wins"], color="navy")

plt.title("NFL 2024: Wins vs Passing Yards")
plt.xlabel("Passing Yards")
plt.ylabel("Wins")

for i in range(len(df)):
    plt.text(df["Passing Yards"][i], df["Wins"][i], df["Team"][i], fontsize=8)

plt.grid(True)
plt.tight_layout()
plt.show()

# Wins vs Rushing Yards

plt.figure(figsize=(10, 6))
plt.scatter(df["Rushing Yards"], df["Wins"], color="green")

plt.title("NFL 2024: Wins vs Rushing Yards")
plt.xlabel("Rushing Yards")
plt.ylabel("Wins")

for i in range(len(df)):
    plt.text(df["Rushing Yards"][i], df["Wins"][i], df["Team"][i], fontsize=8)

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### J) Wins vs Turnovers/Third Down %/RedZone TD Conversion %

# %%
# Wins vs Turnovers

plt.figure(figsize=(10,6))
plt.scatter(df["Turnovers"], df["Wins"], color="darkred")

plt.title("Wins vs Turnovers (2024)")
plt.xlabel("Turnovers")
plt.ylabel("Wins")

for i in range(len(df)):
    plt.text(df["Turnovers"][i], df["Wins"][i], df["Team"][i], fontsize=8)

plt.grid(True)
plt.tight_layout()
plt.show()

# Wins vs Third Down %

plt.figure(figsize=(10, 6))
plt.scatter(df["Third Down %"], df["Wins"], color="orange")
plt.title("Wins vs Third Down % (2024)")
plt.xlabel("Third Down %")
plt.ylabel("Wins")

for i in range(len(df)):
    plt.text(df["Third Down %"][i], df["Wins"][i], df["Team"][i], fontsize=8)

plt.grid(True)
plt.show()

# Wins vs Red Zone TD Conversion %

plt.figure(figsize=(10, 6))
plt.scatter(df["Red Zone TD %"], df["Wins"], color="skyblue")
plt.title("Wins vs Red Zone TD Conversion % (2024)")
plt.xlabel("Red Zone TD %")
plt.ylabel("Wins")

for i in range(len(df)):
    plt.text(df["Red Zone TD %"][i], df["Wins"][i], df["Team"][i], fontsize=8)

plt.grid(True)
plt.show()

# %% [markdown]
# ### K) Third Down %/Red Zone TD Conversion % vs Points Scored

# %%
# Third Down % vs Points Scored

plt.figure(figsize=(10, 6))
plt.scatter(df["Third Down %"], df["Points Scored"], color="darkgreen")

plt.title("Third Down % vs Points Scored (2024)")
plt.xlabel("Third Down %")
plt.ylabel("Points Scored")
plt.grid(True)

# Optionally add team names as labels
for i in range(len(df)):
    plt.text(df["Third Down %"][i], df["Points Scored"][i], df["Team"][i], fontsize=8)

plt.show()

# Red Zone TD Conversion % vs Points Scored

plt.figure(figsize=(10, 6))
plt.scatter(df["Red Zone TD %"], df["Points Scored"], color="darkblue")

plt.title("Red Zone TD % vs Points Scored (2024)")
plt.xlabel("Red Zone Touchdown %")
plt.ylabel("Points Scored")
plt.grid(True)

# Optionally add team names as labels
for i in range(len(df)):
    plt.text(df["Red Zone TD %"][i], df["Points Scored"][i], df["Team"][i], fontsize=8)

plt.show()

# %%
# Correlation Heatmap

import seaborn as sns

plt.figure(figsize=(12, 8))
numeric_df = df.drop(columns=["Team"])  # remove team names for correlation
corr = numeric_df.corr()

sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()
